# %% [markdown]
# # INFO284 Semester Assignment
#
# Initial notebook structure.

# %% [markdown]
# ### Test: Tobias was here 🚀

# %% [markdown]
# ## Tobias test commit

# %%
print("Notebook initialized successfully")
